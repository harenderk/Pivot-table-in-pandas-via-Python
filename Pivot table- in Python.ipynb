# %%
import pandas as pd
import numpy as np

# %%
# importing file in python
data = pd.read_excel('superstore_dataset2011-2015.xlsx')

# %%
data.head() # viewing file
# Out:
#    Row ID         Order ID           Order Date            Ship Date  \
# 0   42433     AG-2011-2040  2011-01-01 00:00:00  2011-06-01 00:00:00
# 1   22253    IN-2011-47883  2011-01-01 00:00:00  2011-08-01 00:00:00
# 2   48883     HU-2011-1220  2011-01-01 00:00:00  2011-05-01 00:00:00
# 3   11731  IT-2011-3647632  2011-01-01 00:00:00  2011-05-01 00:00:00
# 4   22255    IN-2011-47883  2011-01-01 00:00:00  2011-08-01 00:00:00
#
#         Ship Mode Customer ID    Customer Name      Segment         City  \
# 0  Standard Class    TB-11280  Toby Braunhardt     Consumer  Constantine
# 1  Standard Class    JH-15985      Joseph Holt     Consumer  Wagga Wagga
# 2    Second Class      AT-735    Annie Thurman     Consumer     Budapest
# 3    Second Class    EM-14140     Eugene Moren  Home Office    Stockholm
# 4  Standard Class    JH-15985      Joseph Holt     Consumer  Wagga Wagga
#
#              State  ...        Product ID         Category Sub-Category  \
# ...

# %%
c= list(data.columns) # showing columns
print(c)
# Out:
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country', 'Postal Code', 'Market', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost', 'Order Priority']

# %%
# creating pivot table by selecting desired columns
pivot = pd.pivot_table(data,index=['Segment','Order ID','Customer ID','Customer Name'],values=['Sales'],aggfunc=np.sum)

# %%
pivot.head()
# Out:
#                                                        Sales
# Segment  Order ID     Customer ID Customer Name
# Consumer AE-2011-9160 PO-8865     Patrick O'Donnell  161.082
#          AE-2013-1130 EB-4110     Eugene Barchas     228.996
#          AE-2014-2840 PG-8820     Patrick Gardner     42.480
#          AE-2014-3830 GH-4665     Greg Hansen        281.502
#          AE-2014-4120 JD-5790     John Dryer           6.426

# %%
# saving results.
pivot.to_excel('pivot.xlsx')
